# %%
DF_PATH       = "../data/processed/2_cleaned_data.pkl"

ROLE_COLS      = ['DevType']
TECH_COLS      = ['LanguageHaveWorkedWith',
                  'DatabaseHaveWorkedWith',
                  #'PlatformHaveWorkedWith',
                  'WebframeHaveWorkedWith',
                  'MiscTechHaveWorkedWith',
                  'ToolsTechHaveWorkedWith',
                  'NEWCollabToolsHaveWorkedWith',
                  ]

MLFLOW_TRACKING_URI = '../models/mlruns'
MLFLOW_EXPERIMENT_NAME = "skills_jobs_stackoverflow"

LOG_PATH = "../models/temp/"
LOG_DATA_PKL    =  "data.pkl"
LOG_MODEL_PKL   =  "model.pkl"
LOG_METRICS_PKL =  "metrics.pkl"

# %%
# Load packages
import pandas as pd 
import numpy as np
import logging
import pickle
import random
import plotly 
import os
from pathlib import Path

import mlflow
from mlflow.tracking import MlflowClient

from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler
from sklearn.pipeline import make_pipeline, FeatureUnion
from sklearn.feature_selection import VarianceThreshold
from sklearn.multioutput import MultiOutputClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

from sklearn import metrics
from sklearn.metrics import auc, accuracy_score, confusion_matrix, f1_score, precision_score, recall_score

from sklearn.decomposition import PCA, KernelPCA

from sklearn import tree
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

from matplotlib import pyplot as plt

# %% [markdown]
# _________

# %% [markdown]
# ### Functions

# %%
def calculate_quality(ground_truth, predictions, metric_function, sort_values=False):
    quality_scores = {}
    for col in predictions.columns:
        role_pred  = predictions[col].copy()
        role_truth = ground_truth[col].copy()
        quality_scores[col] = round(metric_function(role_truth, role_pred) * 100, 2)
        
    quality_scores = pd.Series(quality_scores.values(), index=quality_scores.keys())
    if sort_values:
        quality_scores = quality_scores.sort_values()
    
    return quality_scores

# %% [markdown]
# -------------

# %% [markdown]
# ## Prep data

# %%
# Read Data
df = pd.read_pickle(DF_PATH)

# %% [markdown]
# ### Balance classes

# %%
# Check the total samples of roles
roles_df = df["DevType"].copy()
roles_df.sum(axis=0)
# Out:
# Academic researcher                               1430
# Data or business analyst                          1410
# Data scientist or machine learning specialist     1803
# Database administrator                            1027
# DevOps specialist                                 1985
# Developer, QA or test                             1065
# Developer, back-end                              13160
# Developer, desktop or enterprise applications     4029
# Developer, embedded applications or devices       1544
# Developer, front-end                              7300
# Developer, full-stack                            13990
# Developer, game or graphics                        855
# Developer, mobile                                 3633
# Engineer, data                                    1344
# Scientist                                          775
# System administrator                              1311
# dtype: int64

# %%
# Resample roles
samples_per_class = 1200
resampled_roles = []

for role_col in roles_df.columns:
    sub_df = roles_df.loc[roles_df[role_col] == 1].copy()

    if len(sub_df) < samples_per_class:
        # Upsample
        sub_df = sub_df.sample(samples_per_class, replace=True, random_state=0)
    else:
        # Downsample
        sub_df = sub_df.sample(samples_per_class, random_state=0)

    resampled_roles.append(sub_df)

# %%
# Construct dfs
roles_df = pd.concat(resampled_roles)
df = df.loc[roles_df.index].copy()

# %%
roles_df.sum(axis=0)
# Out:
# Academic researcher                              2470
# Data or business analyst                         2124
# Data scientist or machine learning specialist    2712
# Database administrator                           1864
# DevOps specialist                                2164
# Developer, QA or test                            1617
# Developer, back-end                              6826
# Developer, desktop or enterprise applications    2960
# Developer, embedded applications or devices      1816
# Developer, front-end                             3027
# Developer, full-stack                            5845
# Developer, game or graphics                      1559
# Developer, mobile                                2334
# Engineer, data                                   2088
# Scientist                                        1915
# System administrator                             2012
# dtype: int64

# %% [markdown]
# ## Split to train and test

# %%
X_train, X_test, Y_train, Y_test = train_test_split(df.drop('DevType', axis=1),
                                                    df['DevType'],
                                                    random_state=0)
# Out:
# /tmp/ipykernel_497688/2536690730.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   X_train, X_test, Y_train, Y_test = train_test_split(df.drop('DevType', axis=1),

# %% [markdown]
# _________

# %% [markdown]
# # Train models

# %% [markdown]
# ### Initialize MLflow

# %%
# Initialize client and experiment
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)
client = MlflowClient()
mlflow.get_experiment_by_name(MLFLOW_EXPERIMENT_NAME)
exp = client.get_experiment_by_name(MLFLOW_EXPERIMENT_NAME)

# %% [markdown]
# ### 1. Vanilla Forest

# %%
rf_clf = make_pipeline(RobustScaler(),
                       PCA(n_components=0.95),
                       RandomForestClassifier(n_jobs=8,
                                              verbose=1,
                                              random_state=0))

rf_clf.fit(X_train.values, Y_train.values)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    9.7s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:   27.1s finished
# Pipeline(steps=[('robustscaler', RobustScaler()),
#                 ('pca', PCA(n_components=0.95)),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(n_jobs=8, random_state=0, verbose=1))])

# %%
# Evaluate on train set
predictions =  pd.DataFrame(rf_clf.predict(X_train.values),
                            columns=Y_train.columns)
train_scores = {score.__name__: calculate_quality(Y_train, predictions, score) 
                for score in [accuracy_score, precision_score, recall_score, f1_score]}
train_scores = pd.concat(train_scores,axis=1)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    4.5s finished

# %%
# Evaluate on test set
predictions =  pd.DataFrame(rf_clf.predict(X_test.values),
                            columns=Y_test.columns)
test_scores = {score.__name__: calculate_quality(Y_test, predictions, score) 
                for score in [accuracy_score, precision_score, recall_score, f1_score]}
test_scores = pd.concat(test_scores,axis=1)
mean_test_scores = test_scores.mean()
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    2.1s finished

# %%
print(test_scores.mean())
test_scores.sort_values("precision_score")
# Out:
# accuracy_score     93.354375
# precision_score    93.240625
# recall_score       60.541250
# f1_score           72.808750
# dtype: float64
#                                                accuracy_score  \
# Developer, full-stack                                   83.71
# Developer, back-end                                     80.15
# Developer, front-end                                    89.50
# Developer, desktop or enterprise applications           89.69
# Data scientist or machine learning specialist           95.33
# Developer, embedded applications or devices             95.65
# Developer, mobile                                       95.73
# System administrator                                    94.77
# Scientist                                               97.42
# Academic researcher                                     95.50
# Data or business analyst                                94.96
# Database administrator                                  97.40
# Engineer, data                                          94.96
# DevOps specialist                                       94.42
# Developer, QA or test                                   96.60
# Developer, game or graphics                             97.88
#
#                                                precision_score  recall_score  \
# Developer, full-stack                                    82.82         59.91
# Developer, back-end                                      84.75         56.25
# Developer, front-end                                     90.91         39.59
# Developer, desktop or enterprise applications            91.12         40.66
# Data scientist or machine learning specialist            91.17         74.30
# Developer, embedded applications or devices              91.73         55.34
# Developer, mobile                                        93.77         65.53
# System administrator                                     93.88         54.22
# Scientist                                                94.96         78.38
# Academic researcher                                      95.77         67.33
# Data or business analyst                                 95.78         58.24
# Database administrator                                   95.98         76.50
# Engineer, data                                           96.11         54.08
# DevOps specialist                                        96.64         50.00
# Developer, QA or test                                    97.70         61.89
# Developer, game or graphics                              98.76         76.44
#
#                                                f1_score
# Developer, full-stack                             69.52
# Developer, back-end                               67.62
# Developer, front-end                              55.16
# Developer, desktop or enterprise applications     56.23
# Data scientist or machine learning specialist     81.88
# Developer, embedded applications or devices       69.04
# Developer, mobile                                 77.15
# System administrator                              68.74
# Scientist                                         85.88
# Academic researcher                               79.07
# Data or business analyst                          72.44
# Database administrator                            85.14
# Engineer, data                                    69.21
# DevOps specialist                                 65.90
# Developer, QA or test                             75.78
# Developer, game or graphics                       86.18

# %% [markdown]
# ### Log

# %%
## Log
# Data details
data_details = {"data_path": DF_PATH,
                "training_indices": X_train.index.tolist(),
                "test_indices": X_test.index.tolist(),
                "features_names": X_train.columns.droplevel(0).tolist(),
                "targets_names": Y_train.columns.tolist()}

with open(os.path.join(LOG_PATH, LOG_DATA_PKL), "wb") as output_file:
    pickle.dump(data_details, output_file)

# %%
# Model
model = {"model_description": "Random Forest: with PCA - Basic",
         "model_details": str(rf_clf),
         "model_object": rf_clf}

with open(os.path.join(LOG_PATH, LOG_MODEL_PKL), "wb") as output_file:
    pickle.dump(model, output_file)

# %%
# Performance details
classes_metrics = {"train_scores": train_scores,
                   "test_scores": test_scores}

with open(os.path.join(LOG_PATH, LOG_METRICS_PKL), "wb") as output_file:
    pickle.dump(classes_metrics, output_file)

# %%
# Start a new run and track
with mlflow.start_run(experiment_id=exp.experiment_id,
                      run_name=model["model_description"]):
    # Log pickles
    mlflow.log_artifacts(LOG_PATH)

    # Track metrics
    for metric, score in mean_test_scores.items():
        mlflow.log_metric(metric, score)

# %% [markdown]
# ______________

# %% [markdown]
# ### 2. Hyper parameter tuning

# %%
hpt_rf_clf = make_pipeline(RobustScaler(),
                           PCA(),
                           RandomForestClassifier(n_jobs=8,
                                                  verbose=1,
                                                  random_state=0))

# %%
# list(hpt_rf_clf.get_params().keys())
tuned_parameters = [{
    'pca__n_components': [0.7, 0.85, 0.95],
    'randomforestclassifier__n_estimators': [250, 500],
    'randomforestclassifier__max_depth':    [3, 10, None],
}]

# %%
hpt_rf_clf = GridSearchCV(hpt_rf_clf, tuned_parameters)
hpt_rf_clf.fit(X_train.values, Y_train.values)
# Out:
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:   10.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   16.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   19.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.5s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=8)]: Done 235 out of 250 | elapsed:    9.1s remaining:    0.6s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    9.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    9.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=8)]: Done 235 out of 250 | elapsed:   10.2s remaining:    0.6s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   10.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=8)]: Done 235 out of 250 | elapsed:    9.1s remaining:    0.6s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    9.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:   13.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   19.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    5.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    6.4s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:   13.8s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   19.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    5.6s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:   14.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   20.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    5.1s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:   14.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   19.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    5.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   19.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   22.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    5.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   15.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   20.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    3.1s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   17.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   23.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    3.0s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   15.8s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   20.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    3.1s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   16.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   21.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   15.7s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   20.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    3.0s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   15.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   35.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   40.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    6.0s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   16.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   36.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   40.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    4.1s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   12.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   29.8s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   34.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    6.0s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   16.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   35.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   40.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    6.3s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   15.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   35.8s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   41.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    6.1s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   23.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   29.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.1s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   18.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   25.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    5.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   22.9s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   29.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    3.2s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   21.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   29.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    4.1s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   22.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   28.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.9s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   17.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   41.9s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   47.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   16.8s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   39.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   45.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   16.9s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   39.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   45.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   16.9s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   39.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   44.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.9s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   16.9s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   38.8s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   44.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    4.0s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=8)]: Done 235 out of 250 | elapsed:    8.9s remaining:    0.6s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    9.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    9.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=8)]: Done 235 out of 250 | elapsed:    8.9s remaining:    0.6s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    9.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=8)]: Done 235 out of 250 | elapsed:    9.0s remaining:    0.6s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    9.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=8)]: Done 235 out of 250 | elapsed:    9.1s remaining:    0.6s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    9.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:   13.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   18.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.6s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   16.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   19.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.5s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:   12.9s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   18.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:   13.2s
# [Parallel(n_jobs=8)]: Done 485 out of 500 | elapsed:   18.3s remaining:    0.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   18.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.6s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:   13.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   18.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.6s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   16.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   21.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   16.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   21.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   15.8s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   21.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   15.9s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   21.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   16.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   21.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   16.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   37.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   42.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.6s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   16.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   37.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   42.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.6s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   16.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   37.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   42.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.4s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   16.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   37.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   42.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.5s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   16.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   37.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   43.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   24.6s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   32.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.9s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   25.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   33.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   24.9s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   32.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.9s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   25.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   33.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    5.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   24.8s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   33.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    5.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   25.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   58.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:  1.1min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    4.3s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   24.7s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   57.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:  1.1min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   24.8s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   57.8s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:  1.1min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    5.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   24.9s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   58.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:  1.1min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   24.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   57.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:  1.1min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.9s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   11.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    9.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   12.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   11.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    9.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   12.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   11.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   20.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   23.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.6s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    9.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   20.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   23.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.5s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    9.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   20.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   23.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.6s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    9.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   20.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   23.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.5s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    8.9s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   20.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   23.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.6s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   21.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   28.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   21.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   28.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   21.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   28.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   21.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   28.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   21.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   28.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   21.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   49.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   56.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   21.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   49.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   56.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.6s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   21.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   49.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   56.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.6s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   21.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   49.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   56.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.6s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   21.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   49.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   56.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.6s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   33.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   44.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.0s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   33.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   44.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   36.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   47.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.9s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    6.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   33.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   44.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.9s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   32.8s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   43.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.9s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   33.6s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:  1.5min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   33.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:  1.5min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   33.6s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:  1.5min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    4.0s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   33.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:  1.5min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    4.0s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    6.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   33.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:  1.5min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    4.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   19.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   45.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   51.6s finished
# GridSearchCV(estimator=Pipeline(steps=[('robustscaler', RobustScaler()),
#                                        ('pca', PCA()),
#                                        ('randomforestclassifier',
#                                         RandomForestClassifier(n_jobs=8,
#                                                                random_state=0,
#                                                                verbose=1))]),
#              param_grid=[{'pca__n_components': [0.7, 0.85, 0.95],
#                           'randomforestclassifier__max_depth': [3, 10, None],
#                           'randomforestclassifier__n_estimators': [250, 500]}])

# %%
hpt_rf_clf.best_params_
# Out:
# {'pca__n_components': 0.7,
#  'randomforestclassifier__max_depth': None,
#  'randomforestclassifier__n_estimators': 500}

# %%
# Evaluate on test set
predictions =  pd.DataFrame(hpt_rf_clf.predict(X_train.values),
                            columns=Y_train.columns)
train_scores = {score.__name__: calculate_quality(Y_train, predictions, score) 
                for score in [accuracy_score, precision_score, recall_score, f1_score]}
train_scores = pd.concat(train_scores,axis=1)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   12.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   14.1s finished

# %%
# Evaluate on test set
predictions =  pd.DataFrame(hpt_rf_clf.predict(X_test.values),
                            columns=Y_test.columns)
test_scores = {score.__name__: calculate_quality(Y_test, predictions, score) 
                for score in [accuracy_score, precision_score, recall_score, f1_score]}
test_scores = pd.concat(test_scores,axis=1)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    6.0s finished

# %%
print(test_scores.mean())
test_scores
# Out:
# accuracy_score     93.425000
# precision_score    90.393750
# recall_score       63.001875
# f1_score           73.756250
# dtype: float64
#                                                accuracy_score  \
# Academic researcher                                     95.35
# Data or business analyst                                94.79
# Data scientist or machine learning specialist           95.31
# Database administrator                                  97.31
# DevOps specialist                                       94.33
# Developer, QA or test                                   96.60
# Developer, back-end                                     80.62
# Developer, desktop or enterprise applications           89.58
# Developer, embedded applications or devices             95.48
# Developer, front-end                                    90.08
# Developer, full-stack                                   84.38
# Developer, game or graphics                             97.65
# Developer, mobile                                       96.17
# Engineer, data                                          95.15
# Scientist                                               97.25
# System administrator                                    94.75
#
#                                                precision_score  recall_score  \
# Academic researcher                                      93.62         67.82
# Data or business analyst                                 94.58         57.51
# Data scientist or machine learning specialist            87.13         78.56
# Database administrator                                   94.96         76.50
# DevOps specialist                                        89.17         54.05
# Developer, QA or test                                    98.07         61.65
# Developer, back-end                                      81.47         61.39
# Developer, desktop or enterprise applications            86.91         42.46
# Developer, embedded applications or devices              87.50         56.53
# Developer, front-end                                     85.78         47.00
# Developer, full-stack                                    80.41         65.61
# Developer, game or graphics                              98.10         74.28
# Developer, mobile                                        91.55         71.78
# Engineer, data                                           93.27         57.85
# Scientist                                                91.65         79.83
# System administrator                                     92.13         55.21
#
#                                                f1_score
# Academic researcher                               78.66
# Data or business analyst                          71.53
# Data scientist or machine learning specialist     82.63
# Database administrator                            84.73
# DevOps specialist                                 67.31
# Developer, QA or test                             75.71
# Developer, back-end                               70.02
# Developer, desktop or enterprise applications     57.04
# Developer, embedded applications or devices       68.69
# Developer, front-end                              60.73
# Developer, full-stack                             72.26
# Developer, game or graphics                       84.54
# Developer, mobile                                 80.47
# Engineer, data                                    71.41
# Scientist                                         85.33
# System administrator                              69.04

# %% [markdown]
# ## Log

# %%
# Data details
data_details = {"data_path": DF_PATH,
                "training_indices": X_train.index.tolist(),
                "test_indices":     X_test.index.tolist(), 
                "features_names":   X_train.columns.droplevel(0).tolist(),
                "targets_names":    Y_train.columns.tolist()}

with open(os.path.join(LOG_PATH, LOG_DATA_PKL), "wb") as output_file:
    pickle.dump(data_details, output_file)

# %%
# Model
model = {"model_description": "Random Forest: with PCA + Hyperparamter tuning",
         "model_details": str(hpt_rf_clf),
         "model_object": hpt_rf_clf} 

with open(os.path.join(LOG_PATH, LOG_MODEL_PKL), "wb") as output_file:
    pickle.dump(model, output_file)

# %%
# Preformance details
classes_metrics = {"train_scores": train_scores, 
                   "test_scores":  test_scores}

with open(os.path.join(LOG_PATH, LOG_METRICS_PKL), "wb") as output_file:
    pickle.dump(classes_metrics, output_file)

# %%
# Start a new run and track 
with mlflow.start_run(experiment_id=exp.experiment_id, 
                      run_name=model["model_description"]):
    # Log pickles
    mlflow.log_artifacts(LOG_PATH)  
    
    # Track metrics 
    for metric, score in mean_test_scores.items():
        mlflow.log_metric(metric, score)
